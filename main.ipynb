# %%
import players
import stats
import pandas as pd

data = pd.DataFrame(stats.load_from_json('data/sorted_stats.json'))
data.head()
# Out:
#                                                       0
# 2009  {'tm_st_snp': 221.0, 'tm_off_snp': 1039.0, 'tm...  \
# 2010  {'rec_yd': 122.0, 'pts_ppr': 35.2, 'rec_tgt': ...
# 2011  {'rec_yd': 166.0, 'pts_ppr': 31.6, 'rec_tgt': ...
# 2012  {'rec_yd': 275.0, 'pts_ppr': 54.5, 'fum': 2.0,...
# 2013  {'tm_st_snp': 238.0, 'tm_off_snp': 1088.0, 'tm...
#
#                                                      10
# 2009  {'tm_st_snp': 221.0, 'tm_off_snp': 1039.0, 'tm...  \
# 2010  {'tm_st_snp': 223.0, 'tm_off_snp': 985.0, 'tm_...
# 2011  {'tm_st_snp': 266.0, 'tm_off_snp': 1144.0, 'tm...
# 2012  {'tm_st_snp': 239.0, 'tm_off_snp': 1230.0, 'tm...
# 2013  {'tm_st_snp': 231.0, 'tm_off_snp': 1159.0, 'tm...
#
#                                                     100
# 2009  {'idp_tkl_ast': 8.0, 'idp_ff': 4.0, 'pts_ppr':...  \
# 2010  {'tm_st_snp': 233.0, 'tm_off_snp': 1065.0, 'tm...
# 2011  {'idp_tkl_ast': 12.0, 'idp_ff': 1.0, 'pts_ppr'...
# 2012  {'tm_st_snp': 256.0, 'tm_off_snp': 1127.0, 'tm...
# 2013  {'tm_st_snp': 236.0, 'tm_off_snp': 1070.0, 'tm...
#
#                                                    1000
# 2009  {'rank_std': 3282, 'rank_ppr': 3283, 'pos_rank...  \
# 2010  {'rank_std': 3393, 'rank_ppr': 3393, 'pos_rank...
# 2011  {'tm_st_snp': 236.0, 'tm_off_snp': 1112.0, 'tm...
# 2012  {'tm_st_snp': 253.0, 'tm_off_snp': 1126.0, 'tm...
# 2013  {'tm_st_snp': 245.0, 'tm_off_snp': 1183.0, 'tm...
#
#                                                    1001
# 2009                                                NaN  \
# 2010                                                NaN
# 2011  {'rec_yd': 48.0, 'pts_ppr': 11.8, 'fum': 1.0, ...
# 2012  {'tm_st_snp': 266.0, 'tm_off_snp': 1151.0, 'tm...
# 2013  {'tm_st_snp': 111.0, 'tm_off_snp': 505.0, 'tm_...
#
#                                                    1002
# 2009                                                NaN  \
# 2010                                                NaN
# 2011  {'tm_st_snp': 43.0, 'tm_off_snp': 270.0, 'tm_d...
# 2012  {'tm_st_snp': 29.0, 'tm_off_snp': 119.0, 'tm_d...
# 2013  {'tm_st_snp': 51.0, 'tm_off_snp': 256.0, 'tm_d...
#
#                                                    1003
# 2009                                                NaN  \
# 2010                                                NaN
# 2011  {'tm_st_snp': 27.0, 'tm_off_snp': 141.0, 'tm_d...
# 2012  {'rec_yd': 17.0, 'pts_ppr': 7.7, 'fum': 6.0, '...
# 2013  {'tm_st_snp': 288.0, 'tm_off_snp': 1232.0, 'tm...
#
#                                                    1004
# 2009                                                NaN  \
# 2010                                                NaN
# 2011  {'rush_tkl_loss': 17.0, 'rec_yd': 98.0, 'pts_p...
# 2012  {'rush_tkl_loss': 5.0, 'rec_yd': 49.0, 'pts_pp...
# 2013  {'rush_tkl_loss': 15.0, 'rec_yd': 140.0, 'pts_...
#
#                                                    1005
# 2009                                                NaN  \
# 2010                                                NaN
# 2011                                                NaN
# 2012  {'tm_st_snp': 153.0, 'tm_off_snp': 717.0, 'tm_...
# 2013  {'tm_st_snp': 65.0, 'tm_off_snp': 281.0, 'tm_d...
#
#                                                    1006  ...
# 2009                                                NaN  ...  \
# 2010                                                NaN  ...
# 2011  {'tm_st_snp': 238.0, 'tm_off_snp': 1085.0, 'tm...  ...
# 2012  {'tm_st_snp': 257.0, 'tm_off_snp': 1171.0, 'tm...  ...
# 2013  {'tm_st_snp': 288.0, 'tm_off_snp': 1232.0, 'tm...  ...
#
#                                                TEAM_PIT
# 2009  {'rush_tkl_loss': 40.0, 'fum_ret_yd': 89.0, 'r...  \
# 2010  {'st_ff': 4.0, 'rush_tkl_loss': 43.0, 'fum_ret...
# 2011  {'st_ff': 4.0, 'rush_tkl_loss': 39.0, 'fum_ret...
# 2012  {'rush_tkl_loss': 42.0, 'fum_ret_yd': 25.0, 'r...
# 2013  {'st_ff': 2.0, 'rush_tkl_loss': 35.0, 'fum_ret...
#
#                                                 TEAM_SD
# 2009  {'st_ff': 2.0, 'rush_tkl_loss': 39.0, 'fum_ret...  \
# 2010  {'st_ff': 1.0, 'rush_tkl_loss': 34.0, 'fum_ret...
# 2011  {'rush_tkl_loss': 27.0, 'fum_ret_yd': 37.0, 'r...
# 2012  {'st_ff': 2.0, 'rush_tkl_loss': 34.0, 'fum_ret...
# 2013  {'st_ff': 1.0, 'rush_tkl_loss': 23.0, 'fum_ret...
#
#                                                TEAM_SEA
# 2009  {'st_ff': 2.0, 'rush_tkl_loss': 45.0, 'fum_ret...  \
# 2010  {'st_ff': 1.0, 'rush_tkl_loss': 49.0, 'rec_yd'...
# 2011  {'st_ff': 3.0, 'rush_tkl_loss': 45.0, 'fum_ret...
# 2012  {'st_ff': 2.0, 'rush_tkl_loss': 43.0, 'fum_ret...
# 2013  {'st_ff': 2.0, 'rush_tkl_loss': 52.0, 'fum_ret...
#
#                                                 TEAM_SF
# 2009  {'st_ff': 1.0, 'rush_tkl_loss': 41.0, 'fum_ret...  \
# 2010  {'st_ff': 1.0, 'rush_tkl_loss': 30.0, 'fum_ret...
# 2011  {'st_ff': 1.0, 'rush_tkl_loss': 58.0, 'fum_ret...
# 2012  {'st_ff': 3.0, 'rush_tkl_loss': 36.0, 'fum_ret...
# 2013  {'st_ff': 1.0, 'rush_tkl_loss': 61.0, 'fum_ret...
#
#                                                TEAM_STL
# 2009  {'st_ff': 1.0, 'rush_tkl_loss': 40.0, 'fum_ret...  \
# 2010  {'st_ff': 3.0, 'rush_tkl_loss': 42.0, 'fum_ret...
# 2011  {'st_ff': 2.0, 'rush_tkl_loss': 48.0, 'fum_ret...
# 2012  {'st_ff': 1.0, 'rush_tkl_loss': 38.0, 'fum_ret...
# 2013  {'st_ff': 3.0, 'rush_tkl_loss': 41.0, 'fum_ret...
#
#                                                 TEAM_TB
# 2009  {'st_ff': 1.0, 'rush_tkl_loss': 37.0, 'fum_ret...  \
# 2010  {'st_ff': 1.0, 'rush_tkl_loss': 37.0, 'fum_ret...
# 2011  {'rush_tkl_loss': 37.0, 'fum_ret_yd': 20.0, 'r...
# 2012  {'st_ff': 1.0, 'rush_tkl_loss': 39.0, 'fum_ret...
# 2013  {'st_ff': 2.0, 'rush_tkl_loss': 45.0, 'fum_ret...
#
#                                                TEAM_TEN
# 2009  {'rush_tkl_loss': 50.0, 'rec_yd': 3104.0, 'pts...  \
# 2010  {'st_ff': 3.0, 'rush_tkl_loss': 51.0, 'fum_ret...
# 2011  {'st_ff': 1.0, 'rush_tkl_loss': 43.0, 'fum_ret...
# 2012  {'rush_tkl_loss': 50.0, 'fum_ret_yd': 78.0, 'r...
# 2013  {'st_ff': 1.0, 'rush_tkl_loss': 43.0, 'fum_ret...
#
#                                                TEAM_WAS
# 2009  {'st_ff': 3.0, 'rush_tkl_loss': 29.0, 'fum_ret...  \
# 2010  {'st_ff': 4.0, 'rush_tkl_loss': 53.0, 'fum_ret...
# 2011  {'rush_tkl_loss': 34.0, 'fum_ret_yd': 12.0, 'r...
# 2012  {'rush_tkl_loss': 43.0, 'fum_ret_yd': 60.0, 'r...
# 2013  {'rush_tkl_loss': 45.0, 'fum_ret_yd': 82.0, 'r...
#
#                                                     TEN
# 2009  {'fan_pts_allow_rb': 407.78, 'pts_allow_7_13':...  \
# 2010  {'fan_pts_allow_rb': 360.0, 'pts_allow_7_13': ...
# 2011  {'fan_pts_allow_rb': 364.2, 'pts_allow_7_13': ...
# 2012  {'fan_pts_allow_rb': 412.7, 'pts_allow_7_13': ...
# 2013  {'fan_pts_allow_rb': 410.9, 'pts_allow_7_13': ...
#
#                                                     WAS
# 2009  {'fan_pts_allow_rb': 338.6, 'pts_allow_7_13': ...
# 2010  {'fan_pts_allow_rb': 375.7, 'pts_allow_7_13': ...
# 2011  {'fan_pts_allow_rb': 316.8, 'pts_allow_7_13': ...
# 2012  {'fan_pts_allow_rb': 305.6, 'fum_ret_yd': 60.0...
# 2013  {'fan_pts_allow_rb': 417.0, 'fum_ret_yd': 82.0...
#
# [5 rows x 8005 columns]

# %%
for x in data:
    for y in data[x]:        
        print(x,y)
        temp = y
        print(temp)
        if 'pos_rank' in temp and temp['pos_rank'].to_numeric() > 100:
            data[x].drop()
data.head()
# Out:
# 0 {'tm_st_snp': 221.0, 'tm_off_snp': 1039.0, 'tm_def_snp': 1118.0, 'st_tkl_solo': 11.0, 'snp': 286.0, 'rec_tgt': 1.0, 'rec_10_19': 1.0, 'rank_std': 5661, 'rank_ppr': 5662, 'pos_rank_std': None, 'pos_rank_ppr': None, 'kr_ypa': 14.0, 'kr_yd': 14.0, 'kr_lng': 14.0, 'kr': 1.0, 'gs': 2.0, 'gp': 12.0, 'gms_active': 12.0}
# {'tm_st_snp': 221.0, 'tm_off_snp': 1039.0, 'tm_def_snp': 1118.0, 'st_tkl_solo': 11.0, 'snp': 286.0, 'rec_tgt': 1.0, 'rec_10_19': 1.0, 'rank_std': 5661, 'rank_ppr': 5662, 'pos_rank_std': None, 'pos_rank_ppr': None, 'kr_ypa': 14.0, 'kr_yd': 14.0, 'kr_lng': 14.0, 'kr': 1.0, 'gs': 2.0, 'gp': 12.0, 'gms_active': 12.0}
# 0 {'rec_yd': 122.0, 'pts_ppr': 35.2, 'rec_tgt': 23.0, 'rec_td_lng': 8.0, 'rec_10_19': 3.0, 'rec_ypr': 5.68, 'rec_air_yd': 54.0, 'pts_half_ppr': 29.7, 'snp': 718.0, 'penalty_yd': 30.0, 'rec_rz_tgt': 4.0, 'rank_ppr': 224, 'pos_rank_ppr': None, 'tm_off_snp': 985.0, 'gs': 13.0, 'rec_5_9': 6.0, 'st_tkl_solo': 2.0, 'rec_fd': 6.0, 'rec_yar': 68.0, 'rec': 11.0, 'tm_st_snp': 223.0, 'rec_lng': 99.0, 'pts_std': 24.2, 'rank_std': 228, 'rec_20_29': 1.0, 'rec_td': 2.0, 'penalty': 3.0, 'gms_active': 15.0, 'tm_def_snp': 1225.0, 'rec_0_4': 1.0, 'gp': 15.0, 'pos_rank_std': None, 'rec_drop': 2.0, 'bonus_rec_te': 11.0}
# {'rec_yd': 122.0, 'pts_ppr': 35.2, 'rec_tgt': 23.0, 'rec_td_lng': 8.0, 'rec_10_19': 3.0, 'rec_ypr': 5.68, 'rec_air_yd': 54.0, 'pts_half_ppr': 29.7, 'snp': 718.0, 'penalty_yd': 30.0, 'rec_rz_tgt': 4.0, 'rank_ppr': 224, 'pos_rank_ppr': None, 'tm_off_snp': 985.0, 'gs': 13.0, 'rec_5_9': 6.0, 'st_tkl_solo': 2.0, 'rec_fd': 6.0, 'rec_yar': 68.0, 'rec': 11.0, 'tm_st_snp': 223.0, 'rec_lng': 99.0, 'pts_std': 24.2, 'rank_std': 228, 'rec_20_29': 1.0, 'rec_td': 2.0, 'penalty': 3.0, 'gms_active': 15.0, 'tm_def_snp': 1225.0, 'rec_0_4': 1.0, 'gp': 15.0, 'pos_rank_std': None, 'rec_drop': 2.0, 'bonus_rec_te': 11.0}
# 0 {'rec_yd': 166.0, 'pts_ppr': 31.6, 'rec_tgt': 14.0, 'rec_td_lng': 12.0, 'rec_10_19': 3.0, 'rec_ypr': 11.07, 'rec_air_yd': 95.0, 'pts_half_ppr': 27.1, 'snp': 590.0, 'rec_40p': 1.0, 'penalty_yd': 35.0, 'rec_rz_tgt': 2.0, 'rank_ppr': 259, 'pos_rank_ppr': None, 'tm_off_snp': 1045.0, 'gs': 11.0, 'rec_5_9': 1.0, 'st_tkl_solo': 2.0, 'rec_fd': 6.0, 'rec_yar': 71.0, 'rec': 9.0, 'idp_tkl_solo': 1.0, 'tm_st_snp': 234.0, 'rec_lng': 166.0, 'pts_std': 22.6, 'idp_tkl': 1.0, 'rank_std': 266, 'rec_20_29': 1.0, 'rec_td': 1.0, 'penalty': 3.0, 'gms_active': 15.0, 'rec_30_39': 1.0, 'tm_def_snp': 1142.0, 'rec_0_4': 2.0, 'gp': 15.0, 'pos_rank_std': None, 'bonus_rec_te': 9.0}
# {'rec_yd': 166.0, 'pts_ppr': 31.6, 'rec_tgt': 14.0, 'rec_td_lng': 12.0, 'rec_10_19': 3.0, 'rec_ypr': 11.07, 'rec_air_yd': 95.0, 'pts_half_ppr': 27.1, 'snp': 590.0, 'rec_40p': 1.0, 'penalty_yd': 35.0, 'rec_rz_tgt': 2.0, 'rank_ppr': 259, 'pos_rank_ppr': None, 'tm_off_snp': 1045.0, 'gs': 11.0, 'rec_5_9': 1.0, 'st_tkl_solo': 2.0, 'rec_fd': 6.0, 'rec_yar': 71.0, 'rec': 9.0, 'idp_tkl_solo': 1.0, 'tm_st_snp': 234.0, 'rec_lng': 166.0, 'pts_std': 22.6, 'idp_tkl': 1.0, 'rank_std': 266, 'rec_20_29': 1.0, 'rec_td': 1.0, 'penalty': 3.0, 'gms_active': 15.0, 'rec_30_39': 1.0, 'tm_def_snp': 1142.0, 'rec_0_4': 2.0, 'gp': 15.0, 'pos_rank_std': None, 'bonus_rec_te': 9.0}
# 0 {'rec_yd': 275.0, 'pts_ppr': 54.5, 'fum': 2.0, 'rec_tgt': 33.0, 'rec_td_lng': 19.0, 'rec_10_19': 10.0, 'rec_ypr': 11.81, 'rec_air_yd': 146.0, 'pts_half_ppr': 43.0, 'snp': 798.0, 'rec_40p': 1.0, 'penalty_yd': 25.0, 'rank_ppr': 262, 'pos_rank_ppr': None, 'tm_off_snp': 1026.0, 'gs': 15.0, 'rec_5_9': 7.0, 'st_tkl_solo': 2.0, 'kr_yd': 18.0, 'rec_fd': 12.0, 'kr': 1.0, 'rec_yar': 129.0, 'rec': 23.0, 'idp_tkl_solo': 2.0, 'tm_st_snp': 224.0, 'rec_lng': 215.0, 'pts_std': 31.5, 'kr_ypa': 18.0, 'idp_tkl': 2.0, 'rank_std': 286, 'rec_20_29': 1.0, 'rec_td': 1.0, 'penalty': 4.0, 'gms_active': 15.0, 'tm_def_snp': 1149.0, 'rec_0_4': 2.0, 'kr_lng': 18.0, 'gp': 15.0, 'pos_rank_std': None, 'rec_drop': 3.0, 'bonus_rec_te': 23.0}
# {'rec_yd': 275.0, 'pts_ppr': 54.5, 'fum': 2.0, 'rec_tgt': 33.0, 'rec_td_lng': 19.0, 'rec_10_19': 10.0, 'rec_ypr': 11.81, 'rec_air_yd': 146.0, 'pts_half_ppr': 43.0, 'snp': 798.0, 'rec_40p': 1.0, 'penalty_yd': 25.0, 'rank_ppr': 262, 'pos_rank_ppr': None, 'tm_off_snp': 1026.0, 'gs': 15.0, 'rec_5_9': 7.0, 'st_tkl_solo': 2.0, 'kr_yd': 18.0, 'rec_fd': 12.0, 'kr': 1.0, 'rec_yar': 129.0, 'rec': 23.0, 'idp_tkl_solo': 2.0, 'tm_st_snp': 224.0, 'rec_lng': 215.0, 'pts_std': 31.5, 'kr_ypa': 18.0, 'idp_tkl': 2.0, 'rank_std': 286, 'rec_20_29': 1.0, 'rec_td': 1.0, 'penalty': 4.0, 'gms_active': 15.0, 'tm_def_snp': 1149.0, 'rec_0_4': 2.0, 'kr_lng': 18.0, 'gp': 15.0, 'pos_rank_std': None, 'rec_drop': 3.0, 'bonus_rec_te': 23.0}
# 0 {'tm_st_snp': 238.0, 'tm_off_snp': 1088.0, 'tm_def_snp': 1091.0, 'st_tkl_solo': 1.0, 'snp': 593.0, 'rec_ypr': 0.33, 'rec_yd': 5.0, 'rec_yar': 3.0, 'rec_tgt': 6.0, 'rec_rz_tgt': 1.0, 'rec_lng': 5.0, 'rec_drop': 1.0, 'rec_air_yd': 2.0, 'rec_5_9': 1.0, 'rec': 2.0, 'rank_std': 1008, 'rank_ppr': 858, 'pts_std': 0.5, 'pts_ppr': 2.5, 'pts_half_ppr': 1.5, 'pos_rank_std': None, 'pos_rank_ppr': None, 'penalty_yd': 10.0, 'penalty': 1.0, 'gs': 14.0, 'gp': 15.0, 'gms_active': 15.0, 'bonus_rec_te': 2.0}
# {'tm_st_snp': 238.0, 'tm_off_snp': 1088.0, 'tm_def_snp': 1091.0, 'st_tkl_solo': 1.0, 'snp': 593.0, 'rec_ypr': 0.33, 'rec_yd': 5.0, 'rec_yar': 3.0, 'rec_tgt': 6.0, 'rec_rz_tgt': 1.0, 'rec_lng': 5.0, 'rec_drop': 1.0, 'rec_air_yd': 2.0, 'rec_5_9': 1.0, 'rec': 2.0, 'rank_std': 1008, 'rank_ppr': 858, 'pts_std': 0.5, 'pts_ppr': 2.5, 'pts_half_ppr': 1.5, 'pos_rank_std': None, 'pos_rank_ppr': None, 'penalty_yd': 10.0, 'penalty': 1.0, 'gs': 14.0, 'gp': 15.0, 'gms_active': 15.0, 'bonus_rec_te': 2.0}
# 0 {'tm_st_snp': 85.0, 'tm_off_snp': 382.0, 'tm_def_snp': 448.0, 'snp': 85.0, 'rec_ypr': 2.6, 'rec_yd': 26.0, 'rec_yar': 17.0, 'rec_tgt': 2.0, 'rec_lng': 20.0, 'rec_fd': 1.0, 'rec_air_yd': 9.0, 'rec_5_9': 1.0, 'rec_20_29': 1.0, 'rec': 2.0, 'rank_std': 949, 'rank_ppr': 811, 'pts_std': 2.6, 'pts_ppr': 4.6, 'pts_half_ppr': 3.6, 'pos_rank_std': None, 'pos_rank_ppr': None, 'gs': 4.0, 'gp': 5.0, 'gms_active': 5.0, 'bonus_rec_te': 2.0}
# {'tm_st_snp': 85.0, 'tm_off_snp': 382.0, 'tm_def_snp': 448.0, 'snp': 85.0, 'rec_ypr': 2.6, 'rec_yd': 26.0, 'rec_yar': 17.0, 'rec_tgt': 2.0, 'rec_lng': 20.0, 'rec_fd': 1.0, 'rec_air_yd': 9.0, 'rec_5_9': 1.0, 'rec_20_29': 1.0, 'rec': 2.0, 'rank_std': 949, 'rank_ppr': 811, 'pts_std': 2.6, 'pts_ppr': 4.6, 'pts_half_ppr': 3.6, 'pos_rank_std': None, 'pos_rank_ppr': None, 'gs': 4.0, 'gp': 5.0, 'gms_active': 5.0, 'bonus_rec_te': 2.0}
# 0 {'tm_st_snp': 205.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1075.0, 'snp': 484.0, 'rec_ypt': 7.56, 'rec_ypr': 10.08, 'rec_yd': 121.0, 'rec_yar': 41.0, 'rec_tgt': 16.0, 'rec_td_lng': 30.0, 'rec_td': 2.0, 'rec_rz_tgt': 3.0, 'rec_lng': 117.0, 'rec_fd': 5.0, 'rec_air_yd': 80.0, 'rec_5_9': 3.0, 'rec_20_29': 3.0, 'rec_10_19': 2.0, 'rec_0_4': 4.0, 'rec': 12.0, 'rank_std': 381, 'rank_ppr': 377, 'pts_std': 24.1, 'pts_ppr': 36.1, 'pts_half_ppr': 30.1, 'pos_rank_std': None, 'pos_rank_ppr': None, 'gs': 11.0, 'gp': 16.0, 'gms_active': 16.0, 'bonus_rec_te': 12.0}
# {'tm_st_snp': 205.0, 'tm_off_snp': 1054.0, 'tm_def_snp': 1075.0, 'snp': 484.0, 'rec_ypt': 7.56, 'rec_ypr': 10.08, 'rec_yd': 121.0, 'rec_yar': 41.0, 'rec_tgt': 16.0, 'rec_td_lng': 30.0, 'rec_td': 2.0, 'rec_rz_tgt': 3.0, 'rec_lng': 117.0, 'rec_fd': 5.0, 'rec_air_yd': 80.0, 'rec_5_9': 3.0, 'rec_20_29': 3.0, 'rec_10_19': 2.0, 'rec_0_4': 4.0, 'rec': 12.0, 'rank_std': 381, 'rank_ppr': 377, 'pts_std': 24.1, 'pts_ppr': 36.1, 'pts_half_ppr': 30.1, 'pos_rank_std': None, 'pos_rank_ppr': None, 'gs': 11.0, 'gp': 16.0, 'gms_active': 16.0, 'bonus_rec_te': 12.0}
# 0 nan
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4         temp = y
#       5         print(temp)
# ----> 6         if 'pos_rank' in temp and temp['pos_rank'].to_numeric() > 100:
#       7             data[x].drop()
#       8 data.head()
#
# TypeError: argument of type 'float' is not iterable
